# %%
from newsapi import NewsApiClient
import yfinance as yf

from Utils.clean_data_helper import *

'''
If unable to install pygooglenews, try
- pip install "setuptools<58.0"
- pip install feedparser --upgrade
- pip install setuptools
- pip install pygooglenews --upgrade
'''
from pygooglenews import GoogleNews
from tqdm import tqdm
import requests
import json

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Get S&P500 companies' tickers

# %%
response = requests.get('https://stockanalysis.com/list/sp-500-stocks/')
companies_info_df = pd.read_html(response.content)[0]
companies_info_df = companies_info_df.drop(columns=["No.", "Stock Price", "% Change", "Revenue"])
companies_info_df.to_excel("Data/SPY_companies_info.xlsx", index=False)

# %%
# tech stocks, pharma stocks, oil stocks, tobacco stocks and Market
tickers = companies_info_df["Symbol"].to_list()

# %% [markdown]
# # News Data Download
# - newsapi has a limit of 2024-11-01 onwards
# - pygoognews https://github.com/kotartemiy/pygooglenews
# - Some other packages to try out: https://www.newscatcherapi.com/blog/python-web-scraping-libraries-to-mine-news-data

# %%
# Looping over 500 tickers: this run will take a few hours
gn = GoogleNews(lang = 'en')

news_dfs = []
for ticker in tqdm(tickers):
    top = gn.search(ticker)
    entries = top["entries"]
    df_temp = clean_goog_news(entries)
    df_temp["date"] = df_temp["date"].apply(lambda d: pd.to_datetime(d, errors='coerce').date())
    df_temp = df_temp.dropna()
    news_dfs += [df_temp.copy()]

# %%
news_dfs[0]
# Out:
#                              date  \
# 0   Wed, 04 Dec 2024 10:40:07 GMT
# 1   Fri, 06 Dec 2024 18:04:28 GMT
# 2   Fri, 06 Dec 2024 19:37:00 GMT
# 3   Fri, 06 Dec 2024 15:55:00 GMT
# 4   Wed, 04 Dec 2024 06:38:01 GMT
# ..                            ...
# 94  Wed, 04 Dec 2024 08:17:12 GMT
# 95  Wed, 04 Dec 2024 16:47:28 GMT
# 96  Wed, 04 Dec 2024 08:17:19 GMT
# 97  Tue, 26 Nov 2024 08:00:00 GMT
# 98  Sun, 17 Nov 2024 08:00:00 GMT
#
#                                                 title  \
# 0   AAPL Stock Hits New High Despite Sales Slowdow...
# 1   Why Apple Inc. (AAPL) Is the Best Beginner Sto...
# 2   Best Dow Jones Stocks To Watch In December 202...
# 3   Why Apple Doesn't Need Nvidia (NASDAQ:AAPL) - ...
# 4   Apple (AAPL) Faces $1B Class Action Lawsuit Ov...
# ..                                                ...
# 94  Thomasville National Bank Increases Stock Hold...
# 95  Apple (NASDAQ:AAPL) Shares Up 0.3% Following A...
# 96  Granite Harbor Advisors Inc. Buys 3,697 Shares...
# 97  Apple Inc. (AAPL): Developing Advanced LLM Sir...
# 98  Could Buying Apple Today Set You Up for Life? ...
#
#                                                source
# 0   https://news.google.com/rss/articles/CBMilwJBV...
# 1   https://news.google.com/rss/articles/CBMieEFVX...
# 2   https://news.google.com/rss/articles/CBMidEFVX...
# 3   https://news.google.com/rss/articles/CBMieEFVX...
# 4   https://news.google.com/rss/articles/CBMingFBV...
# ..                                                ...
# 94  https://news.google.com/rss/articles/CBMixwFBV...
# 95  https://news.google.com/rss/articles/CBMirgFBV...
# 96  https://news.google.com/rss/articles/CBMivwFBV...
# 97  https://news.google.com/rss/articles/CBMihwFBV...
# 98  https://news.google.com/rss/articles/CBMikAFBV...
#
# [99 rows x 3 columns]

# %% [markdown]
# ## General News
# - Newscatcher for general news not targetted at specific stocks: https://github.com/kotartemiy/newscatcher

# %%
topics = ['tech', 'news', 'business', 'science', 'finance', 'food', 'politics', 'economics', 'travel', 'entertainment', 'music', 'sport', 'world']
all_general_news = pd.DataFrame()

for t in tqdm(topics):
    news_temp = clean_newscatcher_news(t)
    all_general_news = pd.concat([all_general_news, news_temp])
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]
# No. of URLs: 163
# ['facebook.com', 'twitter.com', 'theguardian.com', 'cnet.com', 'wired.com', 'digg.com', 'samsung.com', 'theverge.com', 'mashable.com', 'engadget.com', 'businesswire.com', 'lifehacker.com', 'utoronto.ca', 'eff.org', 'theregister.co.uk', 'pcworld.com', 'prweb.com', 'acm.org', 'techradar.com', 'ndtv.com', 'boingboing.net', 'popularmechanics.com', 'crunchbase.com', 'ycombinator.com', 'macrumors.com', 'cio.com', 'gigaom.com', 'ibtimes.co.uk', 'networkworld.com', 'extremetech.com', 'windows.com', 'dailydot.com', 'gsmarena.com', 'anandtech.com', 'slashgear.com', 'computerweekly.com', 'betanews.com', 'techdirt.com', 'houstonchronicle.com', 'techtimes.com', 'androidcentral.com', 'techspot.com', 'infoq.com', 'macmillan.com', 'windowscentral.com', 'neowin.net', 'phonearena.com', 'tmcnet.com', 'pocket-lint.com', 'cbinsights.com', 'theiet.org', 'thewirecutter.com', 'gizmodo.com.au', 'nerdist.com', 'itworld.com', 'internetsociety.org', 'themarysue.com', 'laptopmag.com', 'wccftech.com', 'ghacks.net', 'singularityhub.com', 'computing.co.uk', 'interestingengineering.com', 'sammobile.com', 'notebookcheck.net', 'guru3d.com', 'techhive.com', 'hothardware.com', 'siliconangle.com', 'information-age.com', 'ibtimes.co.in', 'elon.edu', 'tech.co', 'technewsworld.com', 'itpro.co.uk', 'itnews.com.au', 'lifehacker.com.au', 'cbronline.com', 'datacenterknowledge.com', 'bit-tech.net', 'nextgov.com', 'osnews.com', 'gcn.com', 'afterdawn.com', 'globalspec.com', 'wareable.com', 'privateinternetaccess.com', 'cheddar.com', 'hexus.net', 'mybroadband.co.za', 'komando.com', 'expertreviews.co.uk', 'fiercewireless.com', 'stuff.tv', 'thurrott.com', 'techxplore.com', 'gizchina.com', 'bitrebels.com', 'mobilesyrup.com', 'idg.com.au', 'itworldcanada.com', 'verdict.co.uk', 'webfoundation.org', 'bgr.in', 'businesstech.co.za', 'diginomica.com', 'streamingmedia.com', 'itbusiness.ca', 'betakit.com', 'vator.tv', 'arnnet.com.au', 'circleid.com', 'twice.com', 'gpsworld.com', 'tech.eu', 'cloudwards.net', 'whatech.com', 'itnewsafrica.com', 'ispreview.co.uk', 'windowslatest.com', 'gizbot.com', 'crn.com.au', 'geekzone.co.nz', 'knowtechie.com', 'overclockersclub.com', 'nocamels.com', 'alleywatch.com', 'digitalnewsasia.com', 'get.com', 'nerdreactor.com', 'techshout.com', 'semiengineering.com', 'channelweb.co.uk', 'themobileindian.com', 'design-reuse.com', 'technadu.com', 'goodgearguide.com.au', 'techcabal.com', 'socaltech.com', 'pcworld.co.nz', 'uktech.news', 'iafrikan.com', 'reseller.co.nz', 'geekculture.co', 'increment.com', 'ctovision.com', 'techgoondu.com', 'innotechtoday.com', 'contxto.com', 'unbox.ph', 'newsledge.com', 'techpoint.org', 'newsbytes.ph', 'inferse.com', 'stuff.co.za', 'tabletmonkeys.com', 'technowize.com', 'ehmac.ca', 'gadgetsmagazine.com.ph', 'thetechportal.in', 'jcs.org', 'telefonino.net', 'tailscale.com']
# 100%|██████████| 13/13 [56:31<00:00, 260.92s/it]

# %%
all_general_news["date"] = all_general_news["date"].apply(lambda d: pd.to_datetime(d, errors='coerce', utc=True).date())
all_general_news = all_general_news.dropna()
all_general_news.sort_values(by='date', inplace=True)
all_general_news = all_general_news.reset_index(drop=True)

all_general_news
# Out:
#              date                                              title  \
# 0      1970-01-01                          DAFT.IE PROPERTY MAGAZINE
# 1      2008-08-01                  The World's Oldest Jokes Revealed
# 2      2008-10-18                  Charlie Gasparino on Barack Obama
# 3      2008-10-18                      Was Deregulation The Problem?
# 4      2008-10-18              Is It a Liquidity or Solvency Crisis?
# ...           ...                                                ...
# 28930  2024-12-09  VARIOUS - 2024: Past/Present Compilation (Past...
# 28931  2024-12-09  NITECHORD - Lume (Past Inside The Present US) ...
# 28932  2024-12-09  Where Tyranny Begins: The Justice Department, ...
# 28933  2024-12-10  Could US tariffs ramp-up deflationary forces i...
# 28934  2024-12-15  BCA on why Trump's immigration policies may no...
#
#                                                   source    topic
# 0      https://www.thejournal.ie/river/daft-ie-proper...     news
# 1      https://www.sciencecodex.com/worlds-oldest-jok...  science
# 2                      https://www.realclearmarkets.com/  finance
# 3                      https://www.realclearmarkets.com/  finance
# 4                      https://www.realclearmarkets.com/  finance
# ...                                                  ...      ...
# 28930  https://www.juno.co.uk/products/2024-past-pres...    music
# 28931  https://www.juno.co.uk/products/nitechord-lume...    music
# 28932  https://www.newamerica.org/future-security/eve...     news
# 28933  https://www.investing.com/news/economy/could-u...  finance
# 28934  https://www.investing.com/news/economy/bca-on-...  finance
#
# [28935 rows x 4 columns]

# %%
with pd.ExcelWriter('Data/news_data.xlsx') as writer:
    for i, news_df in tqdm(enumerate(news_dfs)):
        news_df.to_excel(writer, sheet_name=tickers[i], index=False)
    all_general_news.to_excel(writer, sheet_name="General", index=False)
# Close the ExcelWriter object
writer.save()

# %% [markdown]
# # CapIQ Data
# Data is acquired from SMU Library Website https://researchguides.smu.edu.sg/az.php?a=c

# %%
news = pd.ExcelFile('./Data/news_data.xlsx')
news_dict = {
    sheet_name: news.parse(sheet_name) for sheet_name in news.sheet_names if sheet_name != 'General'
}

all_general_news = pd.read_excel('./Data/news_data.xlsx', sheet_name="General")

# %%
capiq_df = pd.read_excel("Data/capiq_news_data.xlsx")
capiq_df = capiq_df.rename(columns = {"Key Developments By Date": "date",
                            "Key Development Headline": "title",
                            "Key Development Sources": "source",
                            "Primary Industry": "topic"
                            })

capiq_df =  capiq_df.drop(columns=["Key Developments by Type", "Key Development Situation"])

# %%
capiq_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 448274 entries, 0 to 448273
# Data columns (total 6 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   date                  448274 non-null  datetime64[ns]
#  1   Company Name(s)       448274 non-null  object
#  2   title                 448274 non-null  object
#  3   source                448274 non-null  object
#  4   Business Description  448274 non-null  object
#  5   topic                 448274 non-null  object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 20.5+ MB

# %%
# Get ticker
capiq_df["Ticker"] = capiq_df["Company Name(s)"].str.replace(r'[^(]*\(|\)[^)]*', '')
capiq_df["Ticker"] = capiq_df["Ticker"].str.split(':').str[-1]
capiq_df["Ticker"] = capiq_df["Ticker"].str.replace(r'[^a-zA-Z]+', '')

capiq_df
# Out:
#              date                                  Company Name(s)  \
# 0      2014-01-01              Motorola Solutions, Inc. (NYSE:MSI)
# 1      2014-01-01                   TE Connectivity plc (NYSE:TEL)
# 2      2014-01-01                Leidos Holdings, Inc. (NYSE:LDOS)
# 3      2014-01-01        MarketAxess Holdings Inc. (NasdaqGS:MKTX)
# 4      2014-01-01  Amgen Inc. (NasdaqGS:AMGN); UCB SA (ENXTBR:UCB)
# ...           ...                                              ...
# 448269 2024-12-04                   CSX Corporation (NasdaqGS:CSX)
# 448270 2024-12-04       UnitedHealth Group Incorporated (NYSE:UNH)
# 448271 2024-12-04        LyondellBasell Industries N.V. (NYSE:LYB)
# 448272 2024-12-04                 Freeport-McMoRan Inc. (NYSE:FCX)
# 448273 2024-12-04                      Intuit Inc. (NasdaqGS:INTU)
#
#                                                     title  \
# 0       Motorola Solutions to Provide IDF's Battlefiel...
# 1       TE Connectivity Brings Advanced Mobile Service...
# 2       Leidos Holdings Receives Follow-On Contract fr...
# 3       MarketAxess Holdings Inc.'s Equity Buyback ann...
# 4       Amgen and UCB Announces Results from Phase 2 T...
# ...                                                   ...
# 448269  CSX Corporation Presents at UBS Global Industr...
# 448270  UnitedHealth Group Incorporated - Analyst/Inve...
# 448271  LyondellBasell Industries N.V. Presents at Gol...
# 448272  Freeport-McMoRan Inc. Presents at Mines and Mo...
# 448273  Intuit Inc. Presents at Wells Fargo 8th Annual...
#
#                                                    source  \
# 0                                                   Other
# 1                                           Business Wire
# 2                                    Datamonitor NewsWire
# 3                            Capital IQ Buybacks Database
# 4                                             PR Newswire
# ...                                                   ...
# 448269  PR Newswire; Business Wire; GlobeNewswire; Com...
# 448270                                      Business Wire
# 448271  PR Newswire; Business Wire; GlobeNewswire; Com...
# 448272                                    Company Website
# 448273      Business Wire; GlobeNewswire; Company Website
#
#                                      Business Description  \
# 0       Motorola Solutions, Inc. provides public safet...
# 1       TE Connectivity plc, together with its subsidi...
# 2       Leidos Holdings, Inc., together with its subsi...
# 3       MarketAxess Holdings Inc., together with its s...
# 4       Amgen Inc. (NasdaqGS:AMGN)Amgen Inc. discovers...
# ...                                                   ...
# 448269  CSX Corporation, together with its subsidiarie...
# 448270  UnitedHealth Group Incorporated operates as a ...
# 448271  LyondellBasell Industries N.V. operates as a c...
# 448272  Freeport-McMoRan Inc. engages in the mining of...
# 448273  Intuit Inc. provides financial management, com...
#
#                                                     topic Ticker
# 0                                Communications Equipment    MSI
# 1                       Electronic Manufacturing Services    TEL
# 2                        Research and Consulting Services   LDOS
# 3                            Financial Exchanges and Data   MKTX
# 4       Amgen Inc. (NasdaqGS:AMGN) (Biotechnology); UC...    UCB
# ...                                                   ...    ...
# 448269                                Rail Transportation    CSX
# 448270                                Managed Health Care    UNH
# 448271                                Commodity Chemicals    LYB
# 448272                                             Copper    FCX
# 448273                               Application Software   INTU
#
# [448274 rows x 7 columns]

# %% [markdown]
# ## Merging CapIQ, PyGoogleNews and NewsCatcher
#
# - CapIQ and PyGoogleNews will be concatenated based on the 'ticker' column
# - CapIQ and NewsCatcher will be concatenated based on the 'topic' column
#     * NewsCatcher has less and defined topics for each news. Hence, 'glove-twitter-25' is used to evaluate which topic for each stock in CapIQ has the closest similarity to the topic in NewsCatcher
#     * Note that 'glove-twitter-25' required both texts to have the same number of words to evaluate its similarity, hence 7 random non-NA rows of the first word of the topic for each stock in CapIQ will be evaluated against each topic found in NewsCatcher

# %%
capiq_df_tickers = capiq_df["Ticker"].unique().tolist()
found_tickers = 0
for t in tqdm(capiq_df_tickers):
    news_temp = capiq_df[capiq_df["Ticker"] == t].copy()
    if t in news_dict:
        curr_news_df = news_dict[t].copy()
        match_topic_newscatcher = get_topic(news_temp["Business Description"].dropna()) # already sorted by ticker, just get the first non-NA topic
        curr_newscatcher = all_general_news[all_general_news["topic"].str.contains(match_topic_newscatcher)].copy()
        news_dict[t] = pd.concat([curr_news_df, news_temp.drop(columns=["Ticker", "Company Name(s)", "Business Description"]), curr_newscatcher])
        news_dict[t]["date"] = news_dict[t]["date"].apply(lambda d: pd.to_datetime(d, errors='coerce', utc=True).date())
        news_dict[t] = news_dict[t].dropna()
        news_dict[t].sort_values(by='date', inplace=True)
        news_dict[t] = news_dict[t].reset_index(drop=True)
        found_tickers += 1
    else:
        continue
print(f"Found tickers: {found_tickers}")
# Out:
# 100%|██████████| 3917/3917 [18:20<00:00,  3.56it/s]
# Found tickers: 496

# %%
news_dict_temp = dict(news_dict)
for t, news in news_dict_temp.items():
    if t not in capiq_df_tickers:
        del news_dict[t]

# %%
# separate into 3 files because github only allows files <100,000mb to be pushed

tickers = list(news_dict.keys())
dfs = list(news_dict.values())

with pd.ExcelWriter(f'Data/news_data_final1.xlsx') as writer:
    for i in tqdm(range(165)):
        dfs[i] = dfs[i].drop_duplicates()
        dfs[i].to_excel(writer, sheet_name=tickers[i], index=False)

with pd.ExcelWriter(f'Data/news_data_final2.xlsx') as writer:
    for i in tqdm(range(165, 330)):
        dfs[i] = dfs[i].drop_duplicates()
        dfs[i].to_excel(writer, sheet_name=tickers[i], index=False)

with pd.ExcelWriter(f'Data/news_data_final3.xlsx') as writer:
    for i in tqdm(range(330,len(dfs))):
        dfs[i] = dfs[i].drop_duplicates()
        dfs[i].to_excel(writer, sheet_name=tickers[i], index=False)
# Out:
# 100%|██████████| 165/165 [00:52<00:00,  3.13it/s]
# 100%|██████████| 165/165 [01:03<00:00,  2.59it/s]
# 100%|██████████| 166/166 [01:23<00:00,  1.98it/s]

# %% [markdown]
# # Removing Similar News within 1 day

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

def cosine_similarity_measure(s1, s2):
    vectorizer = CountVectorizer()
    vectors = vectorizer.fit_transform([s1, s2])
    return cosine_similarity(vectors[0:1], vectors[1:2])

# Example usage:
s1 = "kitten"
s2 = "sitting"
print(cosine_similarity_measure(s1, s2))

# %% [markdown]
# # Stocks Data Download
# - Note that this is not the returns of the stocks data
# - Let's focus on periods 2023-01-01 to 2024-12-01 for this project

# %%
stocks = yf.download(tickers, threads=True, group_by='ticker', start='2014-01-01', end='2024-12-01', multi_level_index=False)
# Out:
# [*********************100%***********************]  503 of 503 completed
#
# 2 Failed downloads:
# ['BF.B']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2014-01-01 -> 2024-12-01)')
# ['BRK.B']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')

# %%
stocks
# Out:
# Ticker           FTNT                                                        \
# Price            Open       High        Low      Close  Adj Close    Volume
# Date
# 2014-01-02   3.832000   3.846000   3.790000   3.804000   3.804000  13465000
# 2014-01-03   3.844000   3.874000   3.786000   3.854000   3.854000  11757000
# 2014-01-06   3.884000   3.944000   3.844000   3.848000   3.848000  24980500
# 2014-01-07   3.864000   3.978000   3.836000   3.966000   3.966000  13815500
# 2014-01-08   3.982000   4.010000   3.932000   3.968000   3.968000  10703000
# ...               ...        ...        ...        ...        ...       ...
# 2024-11-22  94.320000  94.500000  92.330002  92.769997  92.769997   4060500
# 2024-11-25  93.110001  94.900002  92.680000  93.120003  93.120003   8804500
# 2024-11-26  93.970001  96.699997  93.970001  96.440002  96.440002   4729300
# 2024-11-27  96.680000  96.790001  93.860001  94.059998  94.059998   3834700
# 2024-11-29  94.330002  95.470001  94.110001  95.050003  95.050003   2124100
#
# Ticker           SWKS                                   ...         IP  \
# Price            Open       High        Low      Close  ...        Low
# Date                                                    ...
# 2014-01-02  28.299999  28.340000  27.200001  27.400000  ...  45.331272
# 2014-01-03  27.400000  27.750000  27.400000  27.719999  ...  45.265900
# 2014-01-06  27.870001  27.930000  27.350000  27.629999  ...  45.265900
# 2014-01-07  27.650000  28.000000  27.610001  27.790001  ...  45.321934
# 2014-01-08  27.950001  28.040001  27.760000  27.920000  ...  45.321934
# ...               ...        ...        ...        ...  ...        ...
# 2024-11-22  85.000000  85.570000  84.720001  85.410004  ...  58.570000
# 2024-11-25  86.550003  89.070000  86.070000  87.930000  ...  59.169998
# 2024-11-26  88.120003  88.449997  85.720001  86.279999  ...  58.580002
# 2024-11-27  86.279999  87.019997  85.139999  86.800003  ...  58.150002
# 2024-11-29  87.199997  88.639999  87.180000  87.589996  ...  57.959999
#
# Ticker                                           HRL                        \
# Price           Close  Adj Close   Volume       Open       High        Low
# Date
# 2014-01-02  45.574085  28.950808  2305077  22.555000  22.584999  22.315001
# 2014-01-03  45.405983  28.844023  2490965  22.495001  22.559999  22.320000
# 2014-01-06  45.284576  28.766907  2436569  22.545000  22.545000  22.305000
# 2014-01-07  45.723507  29.045732  3005477  22.430000  22.745001  22.430000
# 2014-01-08  45.770203  29.075382  2569775  22.575001  22.580000  22.305000
# ...               ...        ...      ...        ...        ...        ...
# 2024-11-22  59.320000  59.320000  3454800  30.559999  30.870001  30.520000
# 2024-11-25  59.570000  59.570000  6833600  30.980000  31.459999  30.950001
# 2024-11-26  59.110001  59.110001  4450000  31.360001  31.709999  31.230000
# 2024-11-27  58.380001  58.380001  2350800  31.780001  32.060001  31.680000
# 2024-11-29  58.830002  58.830002  1819800  31.900000  32.490002  31.850000
#
# Ticker
# Price           Close  Adj Close   Volume
# Date
# 2014-01-02  22.315001  17.616207  1372000
# 2014-01-03  22.455000  17.726730  1358200
# 2014-01-06  22.395000  17.679358  2499000
# 2014-01-07  22.645000  17.876720  1192600
# 2014-01-08  22.400000  17.683298  1320400
# ...               ...        ...      ...
# 2024-11-22  30.670000  30.670000  1999900
# 2024-11-25  31.430000  31.430000  4316800
# 2024-11-26  31.620001  31.620001  2312200
# 2024-11-27  31.920000  31.920000  2220600
# 2024-11-29  32.430000  32.430000  1904800
#
# [2747 rows x 3018 columns]

# %%
ticker_tz_df = pd.DataFrame()
for t in tickers:
    try:
        ticker_info = yf.Ticker(t)
        ticker_tz = ticker_info.info['timeZoneShortName']
        ticker_tz_temp_df = pd.DataFrame({'Ticker':[t], 'tz':[ticker_tz]})
        ticker_tz_df = pd.concat([ticker_tz_df, ticker_tz_temp_df])
    except:
        print(f'No timezone info for {t}')
# Out:
# No timezone info for BRK.B

# %%
print(f'Timezones of SPY stocks include: {ticker_tz_df.tz.unique()}')
# Out:
# Timezones of SPY stocks include: ['EST']

# %%
market = yf.download(["SPY"], threads=True, group_by='ticker', start='2014-01-01', end='2024-12-01', multi_level_index=False)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
market
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-01-02  183.979996  184.070007  182.479996  182.919998  151.242935
# 2014-01-03  183.229996  183.600006  182.630005  182.889999  151.218140
# 2014-01-06  183.490005  183.559998  182.080002  182.360001  150.779877
# 2014-01-07  183.089996  183.789993  182.949997  183.479996  151.705933
# 2014-01-08  183.449997  183.830002  182.889999  183.520004  151.739014
# ...                ...         ...         ...         ...         ...
# 2024-11-22  593.659973  596.150024  593.150024  595.510010  595.510010
# 2024-11-25  599.520020  600.859985  595.200012  597.530029  597.530029
# 2024-11-26  598.799988  601.330017  598.070007  600.650024  600.650024
# 2024-11-27  600.460022  600.849976  597.280029  598.830017  598.830017
# 2024-11-29  599.659973  603.349976  599.380005  602.549988  602.549988
#
#                Volume
# Date
# 2014-01-02  119636900
# 2014-01-03   81390600
# 2014-01-06  108028200
# 2014-01-07   86144200
# 2014-01-08   96582300
# ...               ...
# 2024-11-22   38226400
# 2024-11-25   42441400
# 2024-11-26   45621300
# 2024-11-27   34000200
# 2024-11-29   30177400
#
# [2747 rows x 6 columns]

# %%
stocks.to_excel("Data/stocks_data.xlsx")

# %%
market.to_excel("Data/market_data.xlsx")
